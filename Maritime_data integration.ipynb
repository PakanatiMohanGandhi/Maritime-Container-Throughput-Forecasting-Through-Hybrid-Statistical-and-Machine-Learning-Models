# %%
import pandas as pd

# %%
la = pd.read_csv(r"C:\Users\Lenovo\Downloads\Port_of_Los_Angeles_-_TEU_Counts_Monthly_And_Calendar_YTD.csv")

# %%
la.head()
# Out:
#   Month-Year                    Date  Monthly Total TEUs  CYTD Total TEUs  \
# 0     Jan-09  01/31/2009 12:00:00 AM           587004.20        587004.20
# 1     Feb-09  02/28/2009 12:00:00 AM           413910.30       1000914.50
# 2     Mar-09  03/31/2009 12:00:00 AM           526487.05       1527401.55
# 3     Apr-09  04/30/2009 12:00:00 AM           532124.15       2059525.70
# 4     May-09  05/31/2009 12:00:00 AM           574827.80       2634353.50
#
#    Previous Year CYTD  % Change Total TEUs CYTD
# 0                 NaN                       NaN
# 1                 NaN                       NaN
# 2                 NaN                       NaN
# 3                 NaN                       NaN
# 4                 NaN                       NaN

# %%
export_constant_US = pd.read_excel(r"C:\Users\Lenovo\Downloads\Exports Merchandise, Customs, constant 2010 US$, millions, seas. adj..xlsx",sheet_name='monthly')

# %%
export_constant_US.columns
# Out:
# Index(['Date', 'Advanced Economies', 'Argentina', 'Australia', 'Belgium',
#        'Brazil', 'Canada', 'Chile', 'China', 'Czech Republic', 'Germany',
#        'Denmark', 'EMDE East Asia & Pacific', 'EMDE Europe & Central Asia',
#        'Emerging Market and Developing Economies (EMDEs)', 'Spain', 'Estonia',
#        'Finland', 'France', 'United Kingdom', 'High Income Countries',
#        'Hong Kong SAR, China', 'Hungary', 'Indonesia', 'Ireland', 'Israel',
#        'Italy', 'Jordan', 'Japan', 'Korea, Rep.',
#        'EMDE Latin America & Caribbean', 'Low-Income Countries (LIC)',
#        'Mexico', 'Middle-Income Countries (MIC)',
#        'EMDE Middle East, North Africa, Afghanistan & Pakistan', 'Malaysia',
#        'Netherlands', 'Peru', 'Philippines', 'Poland', 'Russian Federation',
#        'EMDE South Asia', 'Singapore', 'EMDE Sub-Saharan Africa', 'Slovakia',
#        'Sweden', 'Thailand', 'Turkey', 'Taiwan, China', 'Uganda',
# ...

# %%
Export_constant_us = export_constant_US[['Date','United States']]

# %%
export_current_US = pd.read_excel(r"C:\Users\Lenovo\Downloads\Thesis Datasets\Exports Merchandise, Customs, current US$, millions, seas. adj. (1).xlsx",sheet_name='monthly')

# %%
export_current_US.columns
# Out:
# Index(['Date', 'Angola', 'Albania', 'Advanced Economies', 'Argentina',
#        'Australia', 'Austria', 'Azerbaijan', 'Burundi', 'Belgium',
#        ...
#        'Uganda', 'Ukraine', 'Uruguay', 'United States', 'Venezuela, RB',
#        'Viet Nam', 'World (WBG members)', 'Samoa', 'South Africa', 'Zambia'],
#       dtype='object', length=139)

# %%
Export_current_us = export_current_US[['Date','United States']]

# %%
Export_current_us
# Out:
#         Date  United States
# 0    1995M12        50832.0
# 1    1996M01        50275.0
# 2    1996M02        51625.0
# 3    1996M03        50901.0
# 4    1996M04        51351.0
# ..       ...            ...
# 355  2025M07       178370.5
# 356  2025M08       176074.2
# 357  2025M09            NaN
# 358  2025M10            NaN
# 359  2025M11            NaN
#
# [360 rows x 2 columns]

# %%
import_constant_US = pd.read_excel(r"C:\Users\Lenovo\Downloads\Thesis Datasets\Imports Merchandise, Customs, constant 2010 US$, millions, seas. adj. (1).xlsx",sheet_name='monthly')

# %%
import_constant_US.head()
# Out:
#       Date  Advanced Economies  Argentina  Australia  Austria   Belgium  \
# 0  1995M12            394980.6        NaN   5636.000      NaN  25245.82
# 1  1996M01            420443.9        NaN   6203.912      NaN  27627.69
# 2  1996M02            421230.3        NaN   6385.003      NaN  27839.04
# 3  1996M03            395701.4        NaN   5492.365      NaN  26457.56
# 4  1996M04            415908.3        NaN   6363.270      NaN  27953.25
#
#    Bulgaria    Brazil  Canada  Chile  ...  Singapore  EMDE Sub-Saharan Africa  \
# 0       NaN  4871.923     NaN    NaN  ...   11489.90                      NaN
# 1       NaN  5450.978     NaN    NaN  ...   12221.02                      NaN
# 2       NaN  5284.290     NaN    NaN  ...   12218.50                      NaN
# 3       NaN  5252.052     NaN    NaN  ...   12129.92                      NaN
# 4       NaN  5949.824     NaN    NaN  ...   12120.44                      NaN
#
# ...

# %%
Import_constant_us = import_constant_US[['Date','United States']]

# %%
import_current_US = pd.read_excel(r"C:\Users\Lenovo\Downloads\Thesis Datasets\Imports Merchandise, Customs, current US$, millions, seas. adj. (1).xlsx",sheet_name='monthly')

# %%
import_constant_US.head()
# Out:
#       Date  Advanced Economies  Argentina  Australia  Austria   Belgium  \
# 0  1995M12            394980.6        NaN   5636.000      NaN  25245.82
# 1  1996M01            420443.9        NaN   6203.912      NaN  27627.69
# 2  1996M02            421230.3        NaN   6385.003      NaN  27839.04
# 3  1996M03            395701.4        NaN   5492.365      NaN  26457.56
# 4  1996M04            415908.3        NaN   6363.270      NaN  27953.25
#
#    Bulgaria    Brazil  Canada  Chile  ...  Singapore  EMDE Sub-Saharan Africa  \
# 0       NaN  4871.923     NaN    NaN  ...   11489.90                      NaN
# 1       NaN  5450.978     NaN    NaN  ...   12221.02                      NaN
# 2       NaN  5284.290     NaN    NaN  ...   12218.50                      NaN
# 3       NaN  5252.052     NaN    NaN  ...   12129.92                      NaN
# 4       NaN  5949.824     NaN    NaN  ...   12120.44                      NaN
#
# ...

# %%
Import_current_us = import_current_US[['Date','United States']]

# %%
industry = pd.read_excel(r"C:\Users\Lenovo\Downloads\Thesis Datasets\Industrial Production, constant 2010 US$, seas. adj. (1).xlsx",sheet_name='monthly')

# %%
industry.head()
# Out:
#       Date  Advanced Economies       Austria       Belgium  Bangladesh  \
# 0  1996M01        6.300000e+11  5.310000e+09  5.060000e+09         NaN
# 1  1996M02        6.330000e+11  5.150000e+09  4.940000e+09         NaN
# 2  1996M03        6.310000e+11  5.180000e+09  5.010000e+09         NaN
# 3  1996M04        6.340000e+11  5.050000e+09  5.070000e+09         NaN
# 4  1996M05        6.380000e+11  5.230000e+09  5.050000e+09         NaN
#
#    Bulgaria  Bosnia and Herzegovina  Belarus        Brazil    Barbados  ...  \
# 0       NaN                     NaN      NaN  2.910000e+10  36812021.0  ...
# 1       NaN                     NaN      NaN  3.030000e+10  37407804.0  ...
# 2       NaN                     NaN      NaN  2.900000e+10  35817555.0  ...
# 3       NaN                     NaN      NaN  2.860000e+10  34517272.0  ...
# 4       NaN                     NaN      NaN  3.040000e+10  36672711.0  ...
#
#        Tunisia        Turkey  Uganda  Ukraine  Uruguay  United States  \
# ...

# %%
Industry = industry[['Date','United States']]

# %%
exchange = pd.read_excel(r"C:\Users\Lenovo\Downloads\Thesis Datasets\Official exchange rate, LCU per USD, period average (1).xlsx",sheet_name='monthly')

# %%
exchange.head()
# Out:
#       Date     Aruba  Afghanistan    Angola   Albania  Netherlands Antilles  \
# 0  1996M01  1.788196         47.5   5692.00  95.49209              1.775870
# 1  1996M02  1.785190         47.5   5692.00  99.89610              1.775714
# 2  1996M03  1.788952         47.5  26816.48  99.84114              1.775524
# 3  1996M04  1.789136         47.5  31784.00  99.51955              1.775386
# 4  1996M05  1.789565         47.5  31784.00  99.33935              1.776348
#
#    United Arab Emirates  Argentina  Armenia  Antigua and Barbuda  ...  \
# 0              3.672348   1.000826   402.01                  2.7  ...
# 1              3.672667   1.000714   402.53                  2.7  ...
# 2              3.672667   1.000190   403.30                  2.7  ...
# 3              3.672227   1.000000   405.48                  2.7  ...
# 4              3.672348   1.000000   406.58                  2.7  ...
#
#    Venezuela, RB  Virgin Islands, U.S.  Viet Nam   Vanuatu     Samoa  Kosovo  \
# ...

# %%
Exchange = exchange[['Date','United States']]

# %%
retail_market = pd.read_excel(r"C:\Users\Lenovo\Downloads\Thesis Datasets\Retail Sales Volume Index, seas. adj. (1).xlsx",sheet_name='monthly')

# %%
retail_market.head()
# Out:
#       Date  Advanced Economies   Belgium  Brazil  Canada  Switzerland  \
# 0  1996M01            62.38740  72.12050     NaN     NaN          NaN
# 1  1996M02            63.20339  74.53086     NaN     NaN          NaN
# 2  1996M03            62.75838  72.02511     NaN     NaN          NaN
# 3  1996M04            62.50773  70.76236     NaN     NaN          NaN
# 4  1996M05            62.34340  71.12046     NaN     NaN          NaN
#
#    Czech Republic    Germany  Denmark  EMDE East Asia & Pacific  ...  Romania  \
# 0             NaN  102.57620      NaN                       NaN  ...      NaN
# 1             NaN  102.36540      NaN                       NaN  ...      NaN
# 2             NaN  102.04910      NaN                       NaN  ...      NaN
# 3             NaN  101.38070      NaN                       NaN  ...      NaN
# 4             NaN   99.83993      NaN                       NaN  ...      NaN
#
# ...

# %%
Retails = retail_market[['Date','United States']]

# %%
df = Export_constant_us.copy()

# %%
df.head()
# Out:
#       Date  United States
# 0      NaN            NaN
# 1  1995M12       58903.76
# 2  1996M01       58081.94
# 3  1996M02       59779.40
# 4  1996M03       59047.29

# %%
df = pd.merge(df,Export_current_us,on='Date',suffixes=('_export_constant_us','_export_current_us'))

# %%
df = pd.merge(df,Import_constant_us,on='Date')

# %%
df = pd.merge(df,Import_current_us,on='Date',suffixes=('_import_constant_us','_import_current_us'))

# %%
df
# Out:
#         Date  United States_export_constant_us  \
# 0    1995M12                          58903.76
# 1    1996M01                          58081.94
# 2    1996M02                          59779.40
# 3    1996M03                          59047.29
# 4    1996M04                          59279.46
# ..       ...                               ...
# 355  2025M07                         141898.40
# 356  2025M08                         139476.00
# 357  2025M09                               NaN
# 358  2025M10                               NaN
# 359  2025M11                               NaN
#
#      United States_export_current_us  United States_import_constant_us  \
# 0                            50832.0                          78338.04
# 1                            50275.0                          82712.50
# 2                            51625.0                          83416.95
# 3                            50901.0                          77168.70
# ...

# %%
df = pd.merge(df,Industry,on='Date')

# %%
df
# Out:
#         Date  United States_export_constant_us  \
# 0    1996M01                          58081.94
# 1    1996M02                          59779.40
# 2    1996M03                          59047.29
# 3    1996M04                          59279.46
# 4    1996M05                          59908.04
# ..       ...                               ...
# 354  2025M07                         141898.40
# 355  2025M08                         139476.00
# 356  2025M09                               NaN
# 357  2025M10                               NaN
# 358  2025M11                               NaN
#
#      United States_export_current_us  United States_import_constant_us  \
# 0                            50275.0                          82712.50
# 1                            51625.0                          83416.95
# 2                            50901.0                          77168.70
# 3                            51351.0                          81622.97
# ...

# %%
df = pd.merge(df,Exchange,on='Date',suffixes=('_Industry_production','_Exchange_rate'))

# %%
df
# Out:
#         Date  United States_export_constant_us  \
# 0    1996M01                          58081.94
# 1    1996M02                          59779.40
# 2    1996M03                          59047.29
# 3    1996M04                          59279.46
# 4    1996M05                          59908.04
# ..       ...                               ...
# 354  2025M07                         141898.40
# 355  2025M08                         139476.00
# 356  2025M09                               NaN
# 357  2025M10                               NaN
# 358  2025M11                               NaN
#
#      United States_export_current_us  United States_import_constant_us  \
# 0                            50275.0                          82712.50
# 1                            51625.0                          83416.95
# 2                            50901.0                          77168.70
# 3                            51351.0                          81622.97
# ...

# %%
df = pd.merge(df,Retails,on='Date')

# %%
df.rename(columns={'United States':'Retail_market'},inplace=True)

# %%
df
# Out:
#         Date  United States_export_constant_us  \
# 0    1996M01                          58081.94
# 1    1996M02                          59779.40
# 2    1996M03                          59047.29
# 3    1996M04                          59279.46
# 4    1996M05                          59908.04
# ..       ...                               ...
# 354  2025M07                         141898.40
# 355  2025M08                         139476.00
# 356  2025M09                               NaN
# 357  2025M10                               NaN
# 358  2025M11                               NaN
#
#      United States_export_current_us  United States_import_constant_us  \
# 0                            50275.0                          82712.50
# 1                            51625.0                          83416.95
# 2                            50901.0                          77168.70
# 3                            51351.0                          81622.97
# ...

# %%
la
# Out:
#    Month-Year                    Date  Monthly Total TEUs  CYTD Total TEUs  \
# 0      Jan-09  01/31/2009 12:00:00 AM           587004.20        587004.20
# 1      Feb-09  02/28/2009 12:00:00 AM           413910.30       1000914.50
# 2      Mar-09  03/31/2009 12:00:00 AM           526487.05       1527401.55
# 3      Apr-09  04/30/2009 12:00:00 AM           532124.15       2059525.70
# 4      May-09  05/31/2009 12:00:00 AM           574827.80       2634353.50
# ..        ...                     ...                 ...              ...
# 88     Feb-16  02/29/2016 12:00:00 AM           713721.00              NaN
# 89     Mar-16  03/31/2016 12:00:00 AM           612863.20              NaN
# 90     Jun-16  06/30/2016 12:00:00 AM           676006.90              NaN
# 91     Sep-16  09/30/2016 12:00:00 AM           747707.40              NaN
# 92     Aug-16  08/31/2016 12:00:00 AM           798932.75              NaN
#
#     Previous Year CYTD  % Change Total TEUs CYTD
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               359 non-null    object
#  1   United States_export_constant_us   356 non-null    float64
#  2   United States_export_current_us    356 non-null    float64
#  3   United States_import_constant_us   356 non-null    float64
#  4   United States_import_current_us    356 non-null    float64
#  5   United States_Industry_production  357 non-null    float64
#  6   United States_Exchange_rate        359 non-null    int64
#  7   Retail_market                      357 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 22.6+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'],format='%YM%m')

# %%
df.head()
# Out:
#         Date  United States_export_constant_us  \
# 0 1996-01-01                          58081.94
# 1 1996-02-01                          59779.40
# 2 1996-03-01                          59047.29
# 3 1996-04-01                          59279.46
# 4 1996-05-01                          59908.04
#
#    United States_export_current_us  United States_import_constant_us  \
# 0                          50275.0                          82712.50
# 1                          51625.0                          83416.95
# 2                          50901.0                          77168.70
# 3                          51351.0                          81622.97
# 4                          52012.0                          84402.00
#
#    United States_import_current_us  United States_Industry_production  \
# 0                         65510.37                       1.970000e+11
# 1                         66068.31                       2.000000e+11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               359 non-null    datetime64[ns]
#  1   United States_export_constant_us   356 non-null    float64
#  2   United States_export_current_us    356 non-null    float64
#  3   United States_import_constant_us   356 non-null    float64
#  4   United States_import_current_us    356 non-null    float64
#  5   United States_Industry_production  357 non-null    float64
#  6   United States_Exchange_rate        359 non-null    int64
#  7   Retail_market                      357 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 22.6 KB

# %%
df['Date']
# Out:
# 0     1996-01-01
# 1     1996-02-01
# 2     1996-03-01
# 3     1996-04-01
# 4     1996-05-01
#          ...
# 354   2025-07-01
# 355   2025-08-01
# 356   2025-09-01
# 357   2025-10-01
# 358   2025-11-01
# Name: Date, Length: 359, dtype: datetime64[ns]

# %%
df[(df['Date']<='1996-12-31') & (df['Date'] >= '1996-01-01')]
# Out:
#          Date  United States_export_constant_us  \
# 0  1996-01-01                          58081.94
# 1  1996-02-01                          59779.40
# 2  1996-03-01                          59047.29
# 3  1996-04-01                          59279.46
# 4  1996-05-01                          59908.04
# 5  1996-06-01                          60055.19
# 6  1996-07-01                          59354.82
# 7  1996-08-01                          60804.15
# 8  1996-09-01                          60817.36
# 9  1996-10-01                          62390.96
# 10 1996-11-01                          63451.92
# 11 1996-12-01                          62247.81
#
#     United States_export_current_us  United States_import_constant_us  \
# 0                           50275.0                          82712.50
# 1                           51625.0                          83416.95
# 2                           50901.0                          77168.70
# ...

# %%
pd.Timestamp.today()
# Out:
# Timestamp('2026-02-17 15:56:18.949709')

# %%
df['Date'].dt.day_name()
# Out:
# 0         Monday
# 1       Thursday
# 2         Friday
# 3         Monday
# 4      Wednesday
#          ...
# 354      Tuesday
# 355       Friday
# 356       Monday
# 357    Wednesday
# 358     Saturday
# Name: Date, Length: 359, dtype: object

# %%
df.loc[df.shape[0]-1,'Date'] - df.loc[0,'Date']
# Out:
# Timedelta('10897 days 00:00:00')

# %%
la.head()
# Out:
#   Month-Year                    Date  Monthly Total TEUs  CYTD Total TEUs  \
# 0     Jan-09  01/31/2009 12:00:00 AM           587004.20        587004.20
# 1     Feb-09  02/28/2009 12:00:00 AM           413910.30       1000914.50
# 2     Mar-09  03/31/2009 12:00:00 AM           526487.05       1527401.55
# 3     Apr-09  04/30/2009 12:00:00 AM           532124.15       2059525.70
# 4     May-09  05/31/2009 12:00:00 AM           574827.80       2634353.50
#
#    Previous Year CYTD  % Change Total TEUs CYTD
# 0                 NaN                       NaN
# 1                 NaN                       NaN
# 2                 NaN                       NaN
# 3                 NaN                       NaN
# 4                 NaN                       NaN

# %%
la['Month-Year'] = pd.to_datetime(la['Month-Year'],format = '%b-%y')

# %%
la.head()
# Out:
#   Month-Year                    Date  Monthly Total TEUs  CYTD Total TEUs  \
# 0 2009-01-01  01/31/2009 12:00:00 AM           587004.20        587004.20
# 1 2009-02-01  02/28/2009 12:00:00 AM           413910.30       1000914.50
# 2 2009-03-01  03/31/2009 12:00:00 AM           526487.05       1527401.55
# 3 2009-04-01  04/30/2009 12:00:00 AM           532124.15       2059525.70
# 4 2009-05-01  05/31/2009 12:00:00 AM           574827.80       2634353.50
#
#    Previous Year CYTD  % Change Total TEUs CYTD
# 0                 NaN                       NaN
# 1                 NaN                       NaN
# 2                 NaN                       NaN
# 3                 NaN                       NaN
# 4                 NaN                       NaN

# %%
final_df = pd.merge(la,df,left_on='Month-Year',right_on='Date')

# %%
final_df
# Out:
#    Month-Year                  Date_x  Monthly Total TEUs  CYTD Total TEUs  \
# 0  2009-01-01  01/31/2009 12:00:00 AM           587004.20        587004.20
# 1  2009-02-01  02/28/2009 12:00:00 AM           413910.30       1000914.50
# 2  2009-03-01  03/31/2009 12:00:00 AM           526487.05       1527401.55
# 3  2009-04-01  04/30/2009 12:00:00 AM           532124.15       2059525.70
# 4  2009-05-01  05/31/2009 12:00:00 AM           574827.80       2634353.50
# ..        ...                     ...                 ...              ...
# 88 2016-02-01  02/29/2016 12:00:00 AM           713721.00              NaN
# 89 2016-03-01  03/31/2016 12:00:00 AM           612863.20              NaN
# 90 2016-06-01  06/30/2016 12:00:00 AM           676006.90              NaN
# 91 2016-09-01  09/30/2016 12:00:00 AM           747707.40              NaN
# 92 2016-08-01  08/31/2016 12:00:00 AM           798932.75              NaN
#
#     Previous Year CYTD  % Change Total TEUs CYTD     Date_y  \
# ...

# %%
final_df.drop('Date_y',axis=1,inplace=True)

# %%
final_df.rename(columns={'Date_x':'Date'},inplace=True)

# %%
final_df
# Out:
#    Month-Year                    Date  Monthly Total TEUs  CYTD Total TEUs  \
# 0  2009-01-01  01/31/2009 12:00:00 AM           587004.20        587004.20
# 1  2009-02-01  02/28/2009 12:00:00 AM           413910.30       1000914.50
# 2  2009-03-01  03/31/2009 12:00:00 AM           526487.05       1527401.55
# 3  2009-04-01  04/30/2009 12:00:00 AM           532124.15       2059525.70
# 4  2009-05-01  05/31/2009 12:00:00 AM           574827.80       2634353.50
# ..        ...                     ...                 ...              ...
# 88 2016-02-01  02/29/2016 12:00:00 AM           713721.00              NaN
# 89 2016-03-01  03/31/2016 12:00:00 AM           612863.20              NaN
# 90 2016-06-01  06/30/2016 12:00:00 AM           676006.90              NaN
# 91 2016-09-01  09/30/2016 12:00:00 AM           747707.40              NaN
# 92 2016-08-01  08/31/2016 12:00:00 AM           798932.75              NaN
#
#     Previous Year CYTD  % Change Total TEUs CYTD  \
# ...

# %%
final_df.to_excel('Maritime_data.xlsx',index=False)
